# %% [markdown]
# Cloning GitHub repository to load datasets.

# %%
# !git clone https://github.com/opsteryx/stock-price-prediction

# %% [markdown]
# # Importing necessary libraries

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# %% [markdown]
# ## Predicting the values of stock prices using SVM models and comparing their results.

# %%
dates = []
prices = []

def get_data(filename):
	with open(filename, 'r') as csvfile:
		csvFileReader = csv.reader(csvfile)
		next(csvFileReader)	# skipping column names
		for row in csvFileReader:
			dates.append(int(row[0].split('-')[2]))
			prices.append(float(row[1]))
	return

def predict_price(dates, prices, x):
	dates = np.reshape(dates,(len(dates), 1)) # converting to matrix of n X 1

	svr_rbf = SVR(kernel= 'rbf', C= 1e3, gamma= 0.1) # defining the support vector regression models
	svr_lin = SVR(kernel= 'linear', C= 1e3, gamma = 'auto')
	svr_poly = SVR(kernel= 'poly', C= 1e3, degree= 2, gamma = 'auto')
	svr_rbf.fit(dates, prices) # fitting the data points in the models
	svr_lin.fit(dates, prices)
	svr_poly.fit(dates, prices)

	plt.scatter(dates, prices, color= 'black', label= 'Data') # plotting the initial datapoints
	plt.plot(dates, svr_rbf.predict(dates), color= 'red', label= 'RBF model') # plotting the line made by the RBF kernel
	plt.plot(dates,svr_lin.predict(dates), color= 'green', label= 'Linear model') # plotting the line made by linear kernel
	plt.plot(dates,svr_poly.predict(dates), color= 'blue', label= 'Polynomial model') # plotting the line made by polynomial kernel
	plt.xlabel('Date')
	plt.ylabel('Price')
	plt.title('Support Vector Regression')
	plt.legend()
	plt.show()

	return svr_rbf.predict(np.array(x).reshape(-1,1))[0], svr_lin.predict(np.array(x).reshape(-1,1))[0], svr_poly.predict(np.array(x).reshape(-1,1))[0]

get_data('/content/stocks-price-predictor/stocks_csv_files/META_for svm.csv') # calling get_data method by passing the csv file to it
print("Dates- ", dates)
print("Prices- ", prices)

predicted_price = predict_price(dates, prices, 28)
print("\nThe stock open price for 28th August is:", predicted_price)
print("RBF kernel: $", str(predicted_price[0]))
print("Linear kernel: $", str(predicted_price[1]))
print("Polynomial kernel: $", str(predicted_price[2]))
# Out:
# Dates-  [15, 16, 17, 18, 21, 22, 23, 24, 25]
# Prices-  [306.140015, 300.200012, 293.049988, 279.029999, 283.450012, 292.549988, 288.5, 298.5, 286.130005]
# The stock open price for 28th August is: (251.25421844591037, 281.3400026666792, 279.96731905677666)
# RBF kernel: $ 251.25421844591037
# Linear kernel: $ 281.3400026666792
# Polynomial kernel: $ 279.96731905677666

# %% [markdown]
# # Creating a LSTM model for stock price prediction model.

# %% [markdown]
# Introducing datasets.

# %%
adani_stocks = '/content/stocks-price-predictor/stocks_csv_files/Adani Enterprises Limited.csv'
Microsoft_stocks = '/content/stocks-price-predictor/stocks_csv_files/MSFT.csv'
Meta_stocks = '/content/stocks-price-predictor/stocks_csv_files/META.csv'
dataset = pd.read_csv(Meta_stocks)
dataset
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-01-03  338.299988  341.079987  337.190002  338.540009  338.540009
# 1    2022-01-04  339.950012  343.089996  331.869995  336.529999  336.529999
# 2    2022-01-05  333.019989  335.760010  323.839996  324.170013  324.170013
# 3    2022-01-06  322.820007  339.170013  322.720001  332.459991  332.459991
# 4    2022-01-07  332.739990  337.000000  328.880005  331.790009  331.790009
# ..          ...         ...         ...         ...         ...         ...
# 405  2023-08-15  306.140015  307.230011  300.029999  301.950012  301.950012
# 406  2023-08-16  300.200012  301.079987  294.279999  294.290009  294.290009
# 407  2023-08-17  293.049988  296.049988  284.950012  285.089996  285.089996
# 408  2023-08-18  279.029999  285.690002  274.380005  283.250000  283.250000
# 409  2023-08-21  283.450012  290.500000  281.850006  289.899994  289.899994
#
#        Volume
# 0    14537900
# 1    15998000
# 2    20564500
# 3    27962800
# 4    14722000
# ..        ...
# 405  11623600
# 406  18547700
# 407  23950100
# 408  34061200
# 409  20181500
#
# [410 rows x 7 columns]

# %% [markdown]
# ## Creating DataFrame and preprocessing the data.

# %%
df = dataset[['Date', 'Close']]

df
# Out:
#            Date       Close
# 0    2022-01-03  338.540009
# 1    2022-01-04  336.529999
# 2    2022-01-05  324.170013
# 3    2022-01-06  332.459991
# 4    2022-01-07  331.790009
# ..          ...         ...
# 405  2023-08-15  301.950012
# 406  2023-08-16  294.290009
# 407  2023-08-17  285.089996
# 408  2023-08-18  283.250000
# 409  2023-08-21  289.899994
#
# [410 rows x 2 columns]

# %% [markdown]
# Making a function to change date type from 'object' to 'datetime'.

# %%
import datetime

def str_to_datetime(s):
  split = s.split('-')
  year, month, day = int(split[0]), int(split[1]), int(split[2])
  return datetime.datetime(year=year, month=month, day=day)

datetime_object = str_to_datetime('1986-03-19')
datetime_object
# Out:
# datetime.datetime(1986, 3, 19, 0, 0)

# %% [markdown]
# Applying the function on date column

# %%
df['Date'] = df['Date'].apply(str_to_datetime)
df['Date']

# %% [markdown]
# Changing the index to date.

# %%
df.index = df.pop('Date')
df
# Out:
#                  Close
# Date
# 2022-01-03  338.540009
# 2022-01-04  336.529999
# 2022-01-05  324.170013
# 2022-01-06  332.459991
# 2022-01-07  331.790009
# ...                ...
# 2023-08-15  301.950012
# 2023-08-16  294.290009
# 2023-08-17  285.089996
# 2023-08-18  283.250000
# 2023-08-21  289.899994
#
# [410 rows x 1 columns]

# %% [markdown]
# Plotting the value of stocks.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (10,6))
plt.plot(df.index, df['Close'])

# %% [markdown]
# Creating a function to make windowed df that shows the relation between target date's stock's prices and stock prices three days before.

# %%
import numpy as np

def df_to_windowed_df(dataframe, first_date_str, last_date_str, n=3):
  first_date = str_to_datetime(first_date_str)
  last_date  = str_to_datetime(last_date_str)

  target_date = first_date

  dates = []
  X, Y = [], []

  last_time = False
  while True:
    df_subset = dataframe.loc[:target_date].tail(n+1)

    if len(df_subset) != n+1:
      print(f'Error: Window of size {n} is too large for date {target_date}')
      return

    values = df_subset['Close'].to_numpy()
    x, y = values[:-1], values[-1]

    dates.append(target_date)
    X.append(x)
    Y.append(y)

    next_week = dataframe.loc[target_date:target_date+datetime.timedelta(days=7)]
    next_datetime_str = str(next_week.head(2).tail(1).index.values[0])
    next_date_str = next_datetime_str.split('T')[0]
    year_month_day = next_date_str.split('-')
    year, month, day = year_month_day
    next_date = datetime.datetime(day=int(day), month=int(month), year=int(year))

    if last_time:
      break

    target_date = next_date


    if target_date == last_date:
      last_time = True

  ret_df = pd.DataFrame({})
  ret_df['Target Date'] = dates

  X = np.array(X)
  for i in range(0, n):
    X[:, i]
    ret_df[f'Target-{n-i}'] = X[:, i]

  ret_df['Target'] = Y

  return ret_df

#use end date for MSFT : 2023-08-21
#use end date for adani stocks : 2023-08-22
windowed_df = df_to_windowed_df(df,
                                '2022-01-06',
                                '2023-08-21',
                                n=3)

windowed_df
# Out:
#     Target Date    Target-3    Target-2    Target-1      Target
# 0    2022-01-06  338.540009  336.529999  324.170013  332.459991
# 1    2022-01-07  336.529999  324.170013  332.459991  331.790009
# 2    2022-01-10  324.170013  332.459991  331.790009  328.070007
# 3    2022-01-11  332.459991  331.790009  328.070007  334.369995
# 4    2022-01-12  331.790009  328.070007  334.369995  333.260010
# ..          ...         ...         ...         ...         ...
# 402  2023-08-15  305.739990  301.640015  306.190002  301.950012
# 403  2023-08-16  301.640015  306.190002  301.950012  294.290009
# 404  2023-08-17  306.190002  301.950012  294.290009  285.089996
# 405  2023-08-18  301.950012  294.290009  285.089996  283.250000
# 406  2023-08-21  294.290009  285.089996  283.250000  289.899994
#
# [407 rows x 5 columns]

# %% [markdown]
# Creating a function to get date, X, and Y values from windowed dataframe.

# %%
def windowed_df_to_date_X_y(windowed_dataframe):
  df_as_np = windowed_dataframe.to_numpy()

  dates = df_as_np[:, 0]

  middle_matrix = df_as_np[:, 1:-1]
  X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))

  Y = df_as_np[:, -1]

  return dates, X.astype(np.float32), Y.astype(np.float32)

dates, X, y = windowed_df_to_date_X_y(windowed_df)

dates.shape, X.shape, y.shape
# Out:
# ((407,), (407, 3, 1), (407,))

# %% [markdown]
# # Splitting the dataset in training, validation and testing dataset and plotting it for visualisation.

# %%
q_80 = int(len(dates) * .8)
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], y[q_90:]

plt.figure(figsize = (10,6))
plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %% [markdown]
# # Creating a LSTM neural network for price prediction.

# %%
model = Sequential([layers.Input((3, 1)),
                    layers.LSTM(128),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(64, activation='relu'),
                    layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])

model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 4s 74ms/step - loss: 33820.8516 - mean_absolute_error: 177.0972 - val_loss: 62825.0352 - val_mean_absolute_error: 249.8766
# Epoch 2/100
# 11/11 [==============================] - 0s 13ms/step - loss: 32752.8086 - mean_absolute_error: 174.0340 - val_loss: 60740.3828 - val_mean_absolute_error: 245.6673
# Epoch 3/100
# 11/11 [==============================] - 0s 12ms/step - loss: 30675.1328 - mean_absolute_error: 167.8906 - val_loss: 56486.8242 - val_mean_absolute_error: 236.8483
# Epoch 4/100
# 11/11 [==============================] - 0s 12ms/step - loss: 26770.1914 - mean_absolute_error: 155.8530 - val_loss: 49047.7227 - val_mean_absolute_error: 220.5743
# Epoch 5/100
# 11/11 [==============================] - 0s 14ms/step - loss: 20424.5430 - mean_absolute_error: 133.1005 - val_loss: 36507.3047 - val_mean_absolute_error: 190.0103
# Epoch 6/100
# 11/11 [==============================] - 0s 14ms/step - loss: 11758.5635 - mean_absolute_error: 95.0829 - val_loss: 20916.0117 - val_mean_absolute_error: 143.1567
# Epoch 7/100
# 11/11 [==============================] - 0s 16ms/step - loss: 4454.0991 - mean_absolute_error: 51.3748 - val_loss: 7691.9282 - val_mean_absolute_error: 85.3501
# Epoch 8/100
# 11/11 [==============================] - 0s 12ms/step - loss: 2642.1311 - mean_absolute_error: 38.8040 - val_loss: 3744.1099 - val_mean_absolute_error: 57.9499
# Epoch 9/100
# 11/11 [==============================] - 0s 15ms/step - loss: 2639.2463 - mean_absolute_error: 39.1110 - val_loss: 5007.1860 - val_mean_absolute_error: 67.9936
# Epoch 10/100
# 11/11 [==============================] - 0s 13ms/step - loss: 2413.2009 - mean_absolute_error: 36.9820 - val_loss: 5730.1069 - val_mean_absolute_error: 73.1873
# Epoch 11/100
# 11/11 [==============================] - 0s 14ms/step - loss: 2211.9673 - mean_absolute_error: 34.7288 - val_loss: 5451.2061 - val_mean_absolute_error: 71.2862
# Epoch 12/100
# 11/11 [==============================] - 0s 14ms/step - loss: 1626.0448 - mean_absolute_error: 27.3427 - val_loss: 3922.8484 - val_mean_absolute_error: 59.7796
# Epoch 13/100
# 11/11 [==============================] - 0s 14ms/step - loss: 953.3690 - mean_absolute_error: 15.7473 - val_loss: 2146.5786 - val_mean_absolute_error: 42.8185
# Epoch 14/100
# 11/11 [==============================] - 0s 14ms/step - loss: 621.9537 - mean_absolute_error: 11.0431 - val_loss: 989.7057 - val_mean_absolute_error: 27.1862
# Epoch 15/100
# 11/11 [==============================] - 0s 12ms/step - loss: 428.6923 - mean_absolute_error: 9.9618 - val_loss: 452.4994 - val_mean_absolute_error: 17.3882
# Epoch 16/100
# 11/11 [==============================] - 0s 13ms/step - loss: 300.5672 - mean_absolute_error: 8.4354 - val_loss: 259.5640 - val_mean_absolute_error: 13.6041
# Epoch 17/100
# 11/11 [==============================] - 0s 14ms/step - loss: 223.3082 - mean_absolute_error: 7.8384 - val_loss: 90.6824 - val_mean_absolute_error: 6.9486
# Epoch 18/100
# 11/11 [==============================] - 0s 13ms/step - loss: 174.6508 - mean_absolute_error: 7.6918 - val_loss: 45.5007 - val_mean_absolute_error: 4.8379
# Epoch 19/100
# 11/11 [==============================] - 0s 14ms/step - loss: 131.5095 - mean_absolute_error: 6.5978 - val_loss: 73.8775 - val_mean_absolute_error: 6.6501
# Epoch 20/100
# 11/11 [==============================] - 0s 14ms/step - loss: 106.1295 - mean_absolute_error: 6.6494 - val_loss: 63.6946 - val_mean_absolute_error: 5.2319
# Epoch 21/100
# 11/11 [==============================] - 0s 13ms/step - loss: 101.4834 - mean_absolute_error: 6.7917 - val_loss: 83.7356 - val_mean_absolute_error: 7.9649
# Epoch 22/100
# 11/11 [==============================] - 0s 13ms/step - loss: 94.6107 - mean_absolute_error: 6.6731 - val_loss: 32.4472 - val_mean_absolute_error: 3.5976
# Epoch 23/100
# 11/11 [==============================] - 0s 13ms/step - loss: 84.5756 - mean_absolute_error: 6.1634 - val_loss: 60.2393 - val_mean_absolute_error: 5.2924
# Epoch 24/100
# 11/11 [==============================] - 0s 14ms/step - loss: 78.2602 - mean_absolute_error: 6.0916 - val_loss: 46.8226 - val_mean_absolute_error: 4.5582
# Epoch 25/100
# 11/11 [==============================] - 0s 15ms/step - loss: 69.2074 - mean_absolute_error: 5.3953 - val_loss: 59.0364 - val_mean_absolute_error: 5.3772
# Epoch 26/100
# 11/11 [==============================] - 0s 13ms/step - loss: 78.7137 - mean_absolute_error: 6.2455 - val_loss: 78.6181 - val_mean_absolute_error: 6.4804
# Epoch 27/100
# 11/11 [==============================] - 0s 19ms/step - loss: 77.5990 - mean_absolute_error: 6.0415 - val_loss: 66.9207 - val_mean_absolute_error: 5.8497
# Epoch 28/100
# 11/11 [==============================] - 0s 20ms/step - loss: 66.9232 - mean_absolute_error: 5.3236 - val_loss: 56.0062 - val_mean_absolute_error: 4.9771
# Epoch 29/100
# 11/11 [==============================] - 0s 20ms/step - loss: 75.6115 - mean_absolute_error: 5.6092 - val_loss: 46.6789 - val_mean_absolute_error: 4.6566
# Epoch 30/100
# 11/11 [==============================] - 0s 19ms/step - loss: 65.5876 - mean_absolute_error: 5.0935 - val_loss: 50.4859 - val_mean_absolute_error: 4.6248
# Epoch 31/100
# 11/11 [==============================] - 0s 20ms/step - loss: 67.0359 - mean_absolute_error: 5.2741 - val_loss: 54.6311 - val_mean_absolute_error: 5.1165
# Epoch 32/100
# 11/11 [==============================] - 0s 20ms/step - loss: 63.2759 - mean_absolute_error: 4.9902 - val_loss: 51.9646 - val_mean_absolute_error: 4.9188
# Epoch 33/100
# 11/11 [==============================] - 0s 22ms/step - loss: 62.2061 - mean_absolute_error: 4.9672 - val_loss: 44.0613 - val_mean_absolute_error: 4.4985
# Epoch 34/100
# 11/11 [==============================] - 0s 16ms/step - loss: 65.0317 - mean_absolute_error: 5.0569 - val_loss: 53.9142 - val_mean_absolute_error: 4.9611
# Epoch 35/100
# 11/11 [==============================] - 0s 16ms/step - loss: 63.3881 - mean_absolute_error: 5.1901 - val_loss: 57.1993 - val_mean_absolute_error: 5.3872
# Epoch 36/100
# 11/11 [==============================] - 0s 17ms/step - loss: 60.9817 - mean_absolute_error: 4.8052 - val_loss: 69.3681 - val_mean_absolute_error: 6.5748
# Epoch 37/100
# 11/11 [==============================] - 0s 20ms/step - loss: 64.4942 - mean_absolute_error: 5.0437 - val_loss: 43.0990 - val_mean_absolute_error: 4.2890
# Epoch 38/100
# 11/11 [==============================] - 0s 17ms/step - loss: 62.8135 - mean_absolute_error: 4.9865 - val_loss: 45.6714 - val_mean_absolute_error: 4.5246
# Epoch 39/100
# 11/11 [==============================] - 0s 21ms/step - loss: 63.3280 - mean_absolute_error: 4.9956 - val_loss: 35.8623 - val_mean_absolute_error: 3.9317
# Epoch 40/100
# 11/11 [==============================] - 0s 16ms/step - loss: 74.4230 - mean_absolute_error: 5.6510 - val_loss: 91.6285 - val_mean_absolute_error: 7.7900
# Epoch 41/100
# 11/11 [==============================] - 0s 13ms/step - loss: 68.0872 - mean_absolute_error: 5.4500 - val_loss: 58.5255 - val_mean_absolute_error: 5.1467
# Epoch 42/100
# 11/11 [==============================] - 0s 12ms/step - loss: 66.7201 - mean_absolute_error: 5.2602 - val_loss: 63.4505 - val_mean_absolute_error: 6.1558
# Epoch 43/100
# 11/11 [==============================] - 0s 12ms/step - loss: 63.3719 - mean_absolute_error: 4.9936 - val_loss: 31.2459 - val_mean_absolute_error: 3.6351
# Epoch 44/100
# 11/11 [==============================] - 0s 12ms/step - loss: 75.9392 - mean_absolute_error: 5.9009 - val_loss: 34.1289 - val_mean_absolute_error: 3.6596
# Epoch 45/100
# 11/11 [==============================] - 0s 14ms/step - loss: 62.6506 - mean_absolute_error: 4.9261 - val_loss: 34.3012 - val_mean_absolute_error: 3.6476
# Epoch 46/100
# 11/11 [==============================] - 0s 15ms/step - loss: 61.3479 - mean_absolute_error: 4.7322 - val_loss: 56.1808 - val_mean_absolute_error: 5.2536
# Epoch 47/100
# 11/11 [==============================] - 0s 13ms/step - loss: 63.0156 - mean_absolute_error: 5.0619 - val_loss: 67.3322 - val_mean_absolute_error: 6.2757
# Epoch 48/100
# 11/11 [==============================] - 0s 12ms/step - loss: 61.1085 - mean_absolute_error: 4.8214 - val_loss: 60.3575 - val_mean_absolute_error: 6.0936
# Epoch 49/100
# 11/11 [==============================] - 0s 14ms/step - loss: 62.1059 - mean_absolute_error: 4.8406 - val_loss: 46.1576 - val_mean_absolute_error: 4.6284
# Epoch 50/100
# 11/11 [==============================] - 0s 12ms/step - loss: 61.7847 - mean_absolute_error: 4.8290 - val_loss: 63.7278 - val_mean_absolute_error: 6.0885
# Epoch 51/100
# 11/11 [==============================] - 0s 17ms/step - loss: 63.6662 - mean_absolute_error: 5.0702 - val_loss: 79.1160 - val_mean_absolute_error: 7.2693
# Epoch 52/100
# 11/11 [==============================] - 0s 27ms/step - loss: 64.1794 - mean_absolute_error: 5.0179 - val_loss: 51.8364 - val_mean_absolute_error: 5.3535
# Epoch 53/100
# 11/11 [==============================] - 0s 30ms/step - loss: 66.2244 - mean_absolute_error: 5.3403 - val_loss: 37.6573 - val_mean_absolute_error: 3.9913
# Epoch 54/100
# 11/11 [==============================] - 0s 23ms/step - loss: 63.7582 - mean_absolute_error: 4.9095 - val_loss: 54.5545 - val_mean_absolute_error: 5.5561
# Epoch 55/100
# 11/11 [==============================] - 0s 21ms/step - loss: 62.4850 - mean_absolute_error: 5.0824 - val_loss: 41.7580 - val_mean_absolute_error: 4.3944
# Epoch 56/100
# 11/11 [==============================] - 0s 23ms/step - loss: 62.8148 - mean_absolute_error: 4.8385 - val_loss: 49.2452 - val_mean_absolute_error: 5.0046
# Epoch 57/100
# 11/11 [==============================] - 0s 19ms/step - loss: 64.4784 - mean_absolute_error: 5.0397 - val_loss: 43.5656 - val_mean_absolute_error: 4.4037
# Epoch 58/100
# 11/11 [==============================] - 0s 13ms/step - loss: 61.8573 - mean_absolute_error: 4.9717 - val_loss: 59.1454 - val_mean_absolute_error: 5.7099
# Epoch 59/100
# 11/11 [==============================] - 0s 15ms/step - loss: 66.3753 - mean_absolute_error: 4.9450 - val_loss: 78.5702 - val_mean_absolute_error: 6.2743
# Epoch 60/100
# 11/11 [==============================] - 0s 13ms/step - loss: 65.0205 - mean_absolute_error: 5.1584 - val_loss: 92.3380 - val_mean_absolute_error: 8.1598
# Epoch 61/100
# 11/11 [==============================] - 0s 11ms/step - loss: 63.2164 - mean_absolute_error: 5.1093 - val_loss: 47.6049 - val_mean_absolute_error: 4.7556
# Epoch 62/100
# 11/11 [==============================] - 0s 12ms/step - loss: 61.3900 - mean_absolute_error: 4.7524 - val_loss: 32.8564 - val_mean_absolute_error: 3.7232
# Epoch 63/100
# 11/11 [==============================] - 0s 11ms/step - loss: 61.4090 - mean_absolute_error: 4.9584 - val_loss: 57.3727 - val_mean_absolute_error: 5.8262
# Epoch 64/100
# 11/11 [==============================] - 0s 13ms/step - loss: 65.7651 - mean_absolute_error: 5.1061 - val_loss: 45.2305 - val_mean_absolute_error: 4.5393
# Epoch 65/100
# 11/11 [==============================] - 0s 10ms/step - loss: 60.4202 - mean_absolute_error: 4.7443 - val_loss: 102.6224 - val_mean_absolute_error: 8.6049
# Epoch 66/100
# 11/11 [==============================] - 0s 12ms/step - loss: 63.3716 - mean_absolute_error: 5.0725 - val_loss: 220.0024 - val_mean_absolute_error: 13.7650
# Epoch 67/100
# 11/11 [==============================] - 0s 11ms/step - loss: 103.8426 - mean_absolute_error: 6.6919 - val_loss: 55.0261 - val_mean_absolute_error: 5.0971
# Epoch 68/100
# 11/11 [==============================] - 0s 12ms/step - loss: 78.5033 - mean_absolute_error: 5.9424 - val_loss: 59.5608 - val_mean_absolute_error: 5.0833
# Epoch 69/100
# 11/11 [==============================] - 0s 12ms/step - loss: 88.5245 - mean_absolute_error: 6.8526 - val_loss: 33.9626 - val_mean_absolute_error: 4.1451
# Epoch 70/100
# 11/11 [==============================] - 0s 12ms/step - loss: 85.9399 - mean_absolute_error: 6.2755 - val_loss: 50.9680 - val_mean_absolute_error: 4.8450
# Epoch 71/100
# 11/11 [==============================] - 0s 12ms/step - loss: 72.9734 - mean_absolute_error: 5.7023 - val_loss: 41.5969 - val_mean_absolute_error: 3.9842
# Epoch 72/100
# 11/11 [==============================] - 0s 15ms/step - loss: 64.1977 - mean_absolute_error: 5.0794 - val_loss: 75.4638 - val_mean_absolute_error: 6.9316
# Epoch 73/100
# 11/11 [==============================] - 0s 16ms/step - loss: 78.1869 - mean_absolute_error: 5.7740 - val_loss: 36.3346 - val_mean_absolute_error: 3.7259
# Epoch 74/100
# 11/11 [==============================] - 0s 12ms/step - loss: 68.9807 - mean_absolute_error: 5.4144 - val_loss: 45.6690 - val_mean_absolute_error: 4.5576
# Epoch 75/100
# 11/11 [==============================] - 0s 13ms/step - loss: 63.0445 - mean_absolute_error: 5.1439 - val_loss: 38.0271 - val_mean_absolute_error: 4.0391
# Epoch 76/100
# 11/11 [==============================] - 0s 11ms/step - loss: 61.2063 - mean_absolute_error: 4.8674 - val_loss: 33.3894 - val_mean_absolute_error: 3.6867
# Epoch 77/100
# 11/11 [==============================] - 0s 10ms/step - loss: 68.6266 - mean_absolute_error: 5.4871 - val_loss: 36.2028 - val_mean_absolute_error: 3.7679
# Epoch 78/100
# 11/11 [==============================] - 0s 12ms/step - loss: 63.2164 - mean_absolute_error: 4.9318 - val_loss: 95.9941 - val_mean_absolute_error: 8.1811
# Epoch 79/100
# 11/11 [==============================] - 0s 13ms/step - loss: 70.5056 - mean_absolute_error: 5.5840 - val_loss: 52.5151 - val_mean_absolute_error: 4.9732
# Epoch 80/100
# 11/11 [==============================] - 0s 9ms/step - loss: 69.5723 - mean_absolute_error: 5.3542 - val_loss: 93.7529 - val_mean_absolute_error: 7.1389
# Epoch 81/100
# 11/11 [==============================] - 0s 10ms/step - loss: 83.3602 - mean_absolute_error: 6.3276 - val_loss: 55.4902 - val_mean_absolute_error: 5.1412
# Epoch 82/100
# 11/11 [==============================] - 0s 10ms/step - loss: 70.3994 - mean_absolute_error: 5.5435 - val_loss: 85.0244 - val_mean_absolute_error: 7.4000
# Epoch 83/100
# 11/11 [==============================] - 0s 10ms/step - loss: 64.4146 - mean_absolute_error: 5.0292 - val_loss: 49.6799 - val_mean_absolute_error: 4.9278
# Epoch 84/100
# 11/11 [==============================] - 0s 10ms/step - loss: 68.0125 - mean_absolute_error: 5.1595 - val_loss: 68.6748 - val_mean_absolute_error: 5.9416
# Epoch 85/100
# 11/11 [==============================] - 0s 11ms/step - loss: 68.6371 - mean_absolute_error: 5.4020 - val_loss: 37.4181 - val_mean_absolute_error: 3.9969
# Epoch 86/100
# 11/11 [==============================] - 0s 11ms/step - loss: 68.3163 - mean_absolute_error: 5.3070 - val_loss: 35.6400 - val_mean_absolute_error: 3.8966
# Epoch 87/100
# 11/11 [==============================] - 0s 12ms/step - loss: 68.4718 - mean_absolute_error: 5.3563 - val_loss: 49.0459 - val_mean_absolute_error: 4.7656
# Epoch 88/100
# 11/11 [==============================] - 0s 10ms/step - loss: 62.7012 - mean_absolute_error: 4.9614 - val_loss: 214.2136 - val_mean_absolute_error: 13.5973
# Epoch 89/100
# 11/11 [==============================] - 0s 16ms/step - loss: 111.1435 - mean_absolute_error: 7.4182 - val_loss: 46.5630 - val_mean_absolute_error: 4.3210
# Epoch 90/100
# 11/11 [==============================] - 0s 18ms/step - loss: 92.7527 - mean_absolute_error: 6.5514 - val_loss: 118.6135 - val_mean_absolute_error: 8.6253
# Epoch 91/100
# 11/11 [==============================] - 0s 21ms/step - loss: 73.2612 - mean_absolute_error: 5.6221 - val_loss: 84.4877 - val_mean_absolute_error: 7.4711
# Epoch 92/100
# 11/11 [==============================] - 0s 20ms/step - loss: 72.4825 - mean_absolute_error: 5.5702 - val_loss: 56.7110 - val_mean_absolute_error: 5.3433
# Epoch 93/100
# 11/11 [==============================] - 0s 19ms/step - loss: 64.1843 - mean_absolute_error: 5.1622 - val_loss: 50.6325 - val_mean_absolute_error: 5.0883
# Epoch 94/100
# 11/11 [==============================] - 0s 19ms/step - loss: 63.6601 - mean_absolute_error: 4.9752 - val_loss: 55.6624 - val_mean_absolute_error: 5.4212
# Epoch 95/100
# 11/11 [==============================] - 0s 16ms/step - loss: 61.9742 - mean_absolute_error: 4.9809 - val_loss: 97.8403 - val_mean_absolute_error: 8.4910
# Epoch 96/100
# 11/11 [==============================] - 0s 10ms/step - loss: 60.9926 - mean_absolute_error: 4.8601 - val_loss: 50.4318 - val_mean_absolute_error: 4.9538
# Epoch 97/100
# 11/11 [==============================] - 0s 11ms/step - loss: 64.4060 - mean_absolute_error: 4.8121 - val_loss: 65.8771 - val_mean_absolute_error: 5.7106
# Epoch 98/100
# 11/11 [==============================] - 0s 10ms/step - loss: 65.7558 - mean_absolute_error: 5.0454 - val_loss: 40.5115 - val_mean_absolute_error: 4.1843
# Epoch 99/100
# 11/11 [==============================] - 0s 10ms/step - loss: 64.0665 - mean_absolute_error: 5.0681 - val_loss: 49.8515 - val_mean_absolute_error: 5.0262
# Epoch 100/100
# 11/11 [==============================] - 0s 10ms/step - loss: 62.2818 - mean_absolute_error: 4.9794 - val_loss: 40.9734 - val_mean_absolute_error: 4.2698

# %% [markdown]
# Plotting the model.

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Predicting values using model and plotting results.

# %%
train_predictions = model.predict(X_train).flatten()

plt.figure(figsize = (10,6))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.xlabel('Dates')
plt.ylabel('Stock price')
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 11/11 [==============================] - 3s 11ms/step

# %%
val_predictions = model.predict(X_val).flatten()

plt.figure(figsize = (10,6))
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.xlabel('Dates')
plt.ylabel('Stock price')
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 2/2 [==============================] - 0s 9ms/step

# %%
test_predictions = model.predict(X_test).flatten()

plt.figure(figsize = (10,6))
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xlabel('Dates')
plt.ylabel('Stock price')
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 2/2 [==============================] - 0s 14ms/step

# %%
plt.figure(figsize = (10,6))
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.xlabel('Dates')
plt.ylabel('Stock Closing Price')
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])
